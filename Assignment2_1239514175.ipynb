# %% [markdown]
# <h1>ASSIGNMENT 2 INSTRUCTIONS</h1>

# %% [markdown]
# **An agenticAI workflow is a process where an LLM-based app executes multiple steps to complete a task.**
#
# **This assignment accomplishes the following objectives:**
# 1. Learn two key strategies to improve the quality and success rate of agenticAI workflows: tool use and reflection.
# 2. See how we can invoke tools to provide the LLM access to custom and built-in tools.
# 3.  Create an agenticAI workflow with reflection that prompts the LLM to reflect on (and critique) past output in order to improve it.
#
# **In order to complete the assignmet:**
# 1. Section 1: Assignment setup. Just read through to understand what's already available.
# 2. Section 2: Learn how tools work. Complete coding steps 2.1, 2.2, 2.3, and 2.4.
# 3. Section 3:  Learn how reflection works. Complete coding steps 3.1, 3.2, 3.3, 3.4, and 3.5.
#
# **To submit:**
# 1. Rename the assignment as Assignment2-\<asurite\>
# 2. Runtime -> Restart session and run all
# 3. Ctrl-s
# 4. File -> Download .ipynb
# 5. Submit on Canvas

# %% [markdown]
# # SECTION 1: ASSIGNMENT SETUP (JUST READ THROUGH)

# %% [markdown]
# ### We'll first import the required libraries.

# %%
##############################
##### DO NOT EDIT THIS CELL!!!
##############################

# install the orchestration layer (aisuite) plus the provider SDKs (OpenAI, Groq)
# in Colab, this is typically needed once per new runtime
# !pip install aisuite openai groq
# Out:
# Requirement already satisfied: aisuite in /usr/local/lib/python3.12/dist-packages (0.1.14)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.30.0)
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: docstring-parser<0.16.0,>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from aisuite) (0.15)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from aisuite) (0.27.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->aisuite) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.27.0->aisuite) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->aisuite) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)

# %% [markdown]
# ### We'll now setup the API KEYS and Clients.

# %%
##############################
##### DO NOT EDIT THIS CELL!!!
##############################

import os
import aisuite
from openai import OpenAI
from groq import Groq

# load API KEYS (Google Colab + local env fallback)
try:
  # read the API KEYs from Colab Secrets and expose it as an env variable
  from google.colab import userdata
  os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
  os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
except Exception:
  # read the API KEYs from local env and expose it as an env variable
  os.environ["OPENAI_API_KEY"] = os.environ.get("OPENAI_API_KEY")
  os.environ["GROQ_API_KEY"] = os.environ.get("GROQ_API_KEY")

# create the clients
openai_client = OpenAI()
groq_client = Groq()
aisuite_client = aisuite.Client()

# select the models you want to use
OPENAI_MODEL= "gpt-4.1-mini"
AISUITE_OPENAI_MODEL = "openai:"+OPENAI_MODEL
GROQ_MODEL = "llama-3.3-70b-versatile"
AISUITE_GROQ_MODEL = "groq:"+GROQ_MODEL

# %% [markdown]
# ### The reponses we get back from LLMs aren't always well-formatted. <br> We'll use a custom *show* utility function to print LLM responses.

# %%
##############################
##### DO NOT EDIT THIS CELL!!!
##############################

# a nifty utility function to cleanly diplay your chat outputs
from IPython.display import display, HTML, Markdown

def show(title, text):
    display(HTML(f"""
     <h4>{title}</h4>
     <div style="white-space: pre-wrap; padding-left: 24px;">{text}</div>"""))

# %% [markdown]
# ### Recall from Assignment 1 that the LLM was unable to report the current time. To address this limitation, we will define a custom *get_current_time* tool that the LLM can call when needed to retrieve the current time.

# %%
##############################
##### DO NOT EDIT THIS CELL!!!
##############################

from datetime import datetime

# use custom get_current_time tool to get current time
def get_current_time():
  """
    Use custom code to find current local date/time and day of week
    and return it.
  """
  now = datetime.now()
  return {
      "date_time": now.strftime("%Y-%m-%d %H:%M:%S"),
      "day_of_week": now.strftime("%A"),
      }

# %% [markdown]
# ### Also recall from Assignment 1 that an LLM only has direct access to the information it was trained on and is unaware of events that occurred after its knowledge cutoff date. To address this limitation, we will provide access to a *web_search* tool that the LLM can call when it needs to retrieve current information. Since the OpenAI API provides a built-in web search capability, we will use it directly rather than implementing a custom solution.

# %%
##############################
##### DO NOT EDIT THIS CELL!!!
##############################

import json

# use OpenAI's built-in web_search tool to perform web_search
def openai_web_search(query: str):
  """
    Perform a web search using OpenAI's built-in web_search tool
    and return raw results.
  """
  resp = openai_client.responses.create(
      model=OPENAI_MODEL,
      input=query,
      tools=[{"type": "web_search"}],
  )
  return json.loads(resp.model_dump_json())

# %% [markdown]
# ### The *run_openai_query* function is similar to what we used in Assignment 1, with two key changes. First, it can now accept a list of tools and invoke them as needed. Second, instead of printing the LMM response and usage statistics inline, it returns both the model's response and relevant query details (including usage statistics and any tools that were called).

# %%
##############################
##### DO NOT EDIT THIS CELL!!!
##############################

# used for wall-clock timing for request
import time

def run_openai_query(system_prompt, user_prompt, tools=[]):
  """
    Execute the query, print the prompt, the response, and detailed usage stats.
    Supports tools.
  """

  # start the time before the API call
  start_time = time.time()

  # make chat-completions request thro aisuite, routed to OpenAI-backed model
  completion = aisuite_client.chat.completions.create(
      model=AISUITE_OPENAI_MODEL, # OpenAI-backed model
      messages=[
          {"role": "system", "content": system_prompt}, # system sets global behavior/instructions
           {"role": "user", "content": user_prompt} # user contains the actual task/prompt
      ],
      tools=tools,
      max_turns=3,
  )

  # compute end-to-end wall-clock time for API request
  elapsed_time = time.time() - start_time

  # response
  response = completion.choices[0].message.content.strip()

  # usage stats
  query_details = {}
  query_details["prompt_tokens"]=completion.usage.prompt_tokens
  query_details["completion_tokens"]=completion.usage.completion_tokens
  query_details["total_tokens"]=completion.usage.total_tokens
  if hasattr(completion.usage, 'total_time'):
    query_details["total_time"]=f"{completion.usage.total_time:.2f}s"
  else:
    query_details["total_time"]=f"{elapsed_time:.2f}s"

  # tools invoked
  tools_invoked=[]
  messages = completion.choices[0].intermediate_messages
  for m in messages or []:
    if hasattr(m, "tool_calls") and m.tool_calls:
      for t in m.tool_calls:
        tools_invoked.append(t.function.name)
  query_details["tools_invoked"]=tools_invoked

  return response, query_details

# %% [markdown]
# # SECTION 2: LEARN HOW TOOLS WORK (COMPLETE STEPS 2.1 thro 2.4)

# %% [markdown]
# ### **[Complete Coding STEP-2.1 and STEP-2.2]**: <br> You will now test LLM behavior with and without the custom get_current_time tool. Provide a system_prompt and a user_prompt as indicated below. Then execute the cell to see how that affects LLM behavior. Read inline comments in the cell for expected behavior. Ensure this is reflected in the ouput you see.

# %%
#########################################################################
##### ONLY CODE AS INDICATED - DO NOT ALTER THE CELL IN  ANY OTHER WAY!!!
#########################################################################

# STEP-2.1: Recall that the system prompt sets the global behavior/instructions for the LLM.
#           Enter a system prompt of choice.
#           You will enter your system prompt within the quotes below.
#           Refer to Assignment 1 for an illustration.
system_prompt = (
    f"""
    You are a helpful assistant. Answer questions clearly and accurately

    """
)

# STEP-2.2: Recall that the user prompt contains the actual task/prompt for the LLM.
#           Enter a user prompt to ask for the current time.
#           You will enter your user prompt within the quotes below.
#           Refer to Assignment 1 for an illustration.
user_prompt = (
    f"""
    What is the current local date and time right now?

    """
)

# Recall from Assignment 1 that the LLM did not have access to current time.
# And hence, it couldn't provide the current time.
response, query_details = run_openai_query(system_prompt, user_prompt, tools=[])
show("----- WITHOUT TOOLS -----", "")
show("Query", user_prompt)
show("Query Response", response)
show("Query Details", query_details)

# We'll now give the LLM access to the custom get_current_time tool.
# So now it can provide current time.
# Notice that get_current_time shows up in tools_invoked under "Query Details".
response, query_details = run_openai_query(system_prompt, user_prompt, tools=[get_current_time])
show("----- WITH TOOLS -----", "")
show("Query", user_prompt)
show("Query Response", response)
show("Query Details", query_details)
# Out:
#      <h4>----- WITHOUT TOOLS -----</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;"></div>
#      <h4>Query</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">
#     What is the current local date and time right now?
#
#     </div>
#      <h4>Query Response</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">I do not have access to real-time data, so I cannot provide the current local date and time. You can check the date and time on your device or use an online time service for the most accurate information.</div>
#      <h4>Query Details</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">{'prompt_tokens': 52, 'completion_tokens': 44, 'total_tokens': 96, 'total_time': '1.75s', 'tools_invoked': []}</div>
#      <h4>----- WITH TOOLS -----</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;"></div>
#      <h4>Query</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">
#     What is the current local date and time right now?
#
#     </div>
#      <h4>Query Response</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">The current local date and time is April 5, 2026, 22:34 (10:34 PM), and it is Sunday.</div>
#      <h4>Query Details</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">{'prompt_tokens': 126, 'completion_tokens': 31, 'total_tokens': 157, 'total_time': '1.94s', 'tools_invoked': ['get_current_time']}</div>

# %% [markdown]
# ### **[Complete Coding STEP-2.3 and STEP-2.4]**: <br> You will now test LLM behavior with and without the built-in web_search tool. Provide a system_prompt and a user_prompt as indicated below. Then execute the cell to see how that affects LLM behavior. Read inline comments in the cell for expected behavior. Ensure this is reflected in the ouput you see.

# %%
#########################################################################
##### ONLY CODE AS INDICATED - DO NOT ALTER THE CELL IN  ANY OTHER WAY!!!
#########################################################################

# STEP-2.3: Recall that the system prompt sets the global behavior/instructions for the LLM.
#           Enter a system prompt of choice.
#           You will enter your system prompt within the quotes below.
#           Refer to Assignment 1 for an illustration.
system_prompt = (
    f"""
    You are a helpful assistant. Answer questions clearly and accurately

    """
)

# STEP-2.4: Recall that the user prompt contains the actual task/prompt for the LLM.
#           Enter a user prompt to ask about the Netflix Warner Bros acquisition.
#           You will enter your user prompt within the quotes below.
#           Refer to Assignment 1 for an illustration.
user_prompt = (
    f"""
    Was Warner Bros acquired by Netflix? Use current information.

    """
)

# Recall from Assignment 1 that LLMs don't have information on events
# that occured after their knowledge cut off date (June 2024).
# And hence, it couldn't provide current information.
response, query_details = run_openai_query(system_prompt, user_prompt, tools=[])
show("----- WITHOUT TOOLS -----", "")
show("Query", user_prompt)
show("Query Response", response)
show("Query Details", query_details)

# Let's give the LLM access to the OpenAI's built-in openai_web_search tool.
# So now it can provide current information.
# Notice that openai_web_search shows up in tools_invoked under "Query Details".
# Also notice that it will only invoke the tools it needs to respond.
response, query_details = run_openai_query(system_prompt, user_prompt, tools=[get_current_time, openai_web_search])
show("----- WITH TOOLS -----", "")
show("Query", user_prompt)
show("Query Response", response)
show("Query Details", query_details)
# Out:
#      <h4>----- WITHOUT TOOLS -----</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;"></div>
#      <h4>Query</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">
#     Was Warner Bros acquired by Netflix? Use current information.
#
#     </div>
#      <h4>Query Response</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">No, Warner Bros was not acquired by Netflix. Warner Bros remains a part of Warner Bros. Discovery, a separate entertainment company. Netflix continues to operate independently as a major streaming service.</div>
#      <h4>Query Details</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">{'prompt_tokens': 52, 'completion_tokens': 38, 'total_tokens': 90, 'total_time': '0.72s', 'tools_invoked': []}</div>
#      <h4>----- WITH TOOLS -----</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;"></div>
#      <h4>Query</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">
#     Was Warner Bros acquired by Netflix? Use current information.
#
#     </div>
#      <h4>Query Response</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">As of the most current information available, Netflix announced in December 2025 its plan to acquire Warner Bros. Discovery, Inc. (WBD) in a deal valued at approximately $82.7 billion. This acquisition included Warner Bros.' film and television studios, as well as the streaming services HBO Max and HBO. The deal was structured as a cash and stock transaction and was expected to close after the separation of WBD's Global Networks division into a new publicly traded company, anticipated in the third quarter of 2026.
#
# However, in early 2026, a bidding war occurred when Paramount Skydance made a rival acquisition offer for WBD. Despite Netflix's initial agreement, Warner Bros. Discovery reopened negotiations with Paramount after receiving a contractual waiver from Netflix. As of March 2026, the acquisition by Paramount Skydance was completed.
#
# In summary, Netflix did announce an acquisition deal for Warner Bros., but the final acquisition was completed by Paramount Skydance, not Netflix.</div>
#      <h4>Query Details</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">{'prompt_tokens': 2648, 'completion_tokens': 200, 'total_tokens': 2848, 'total_time': '13.92s', 'tools_invoked': ['openai_web_search']}</div>

# %% [markdown]
# # SECTION 3: LEARN HOW REFLECTION WORKS (COMPLETE STEPS 3.1 thro 3.5)
#
# ### In this section, we will implement an AgenticAI Workflow with Reflection. **Reflection** is the act of pausing to evaluate/judge what was generated before finalizing an answer. In other words, separating generation from judgement so weaknesses can be identified. Specifically, we will implement the following workflow.
# - question -> **DRAFTER (LLM + web_search)** -> draft
# - draft -> **EVALUATOR (LLM)** -> evaluation
# - draft & evaluation -> **REVISER (LLM)** -> revision
# ### NOTE: You may need to iterate on STEPS 3.1-3.5 several times before you are able to settle on the final version for submission.

# %% [markdown]
# ### We'll start by specifiying the **question** we want to pose to the agenticAI workflow. <br> NOTE: You'll want to test the agenticAI workflow with different questions in order to ensure that what you end up with in STEPS 3.1-3.5 generalizes well to a variety of questions. But please ensure that your final submission has the original question as stated below.

# %%
#########################################################################
##### ONLY CODE AS INDICATED - DO NOT ALTER THE CELL IN  ANY OTHER WAY!!!
#########################################################################

# This is the question we are attempting to answer in Section 3.
# You MUST NOT change this question for your final submission.
# However, feel free to test the drafter->evaluator->reviser agenticAI workflow in Section 3
# with different questions to ensure your code in Steps 3.1-3.5 generalizes well.
question = (
    f"""
    What is the latest total investment announced by TSMC for its Arizona fabs, and what does it include?
    """
)

# %% [markdown]
# ### **[Complete Coding STEP-3.1]**:
# We'll now define the **drafter agent**:
# - question -> **DRAFTER (LLM + web_search)** -> draft.
#
# You will first update the system_prompt (STEP 3.1) as you see fit. You will then execute the cell and examine the draft.

# %%
#########################################################################
##### ONLY CODE AS INDICATED - DO NOT ALTER THE CELL IN  ANY OTHER WAY!!!
#########################################################################


# STEP-3.1: You have been provided with a system_prompt for the drafter.
#           Feel free to update the system_prompt if required.
#           But you MUST NOT change the role of the drafter.
draft_system_prompt = (
    f"""
    You are a draft writer.
    Find accurate, up-to-date information.
    Produce a clear, factual response with sources.
    """
)

# We are going to send the question to the drafter
draft_user_prompt = (
    f"""
    Question from user: {question}
    """
)

# Have the LLM model (with web_search) produce a first draft.
draft, query_details = run_openai_query(draft_system_prompt, draft_user_prompt, tools=[openai_web_search])

show("----- DRAFT (WITH WEB_SEARCH) -----", "")
show("Question", draft_user_prompt)
show("Draft", draft)
# Out:
#      <h4>----- DRAFT (WITH WEB_SEARCH) -----</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;"></div>
#      <h4>Question</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">
#     Question from user:
#     What is the latest total investment announced by TSMC for its Arizona fabs, and what does it include?
#
#     </div>
#      <h4>Draft</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">As of early 2026, Taiwan Semiconductor Manufacturing Company (TSMC) has announced a total investment of approximately $165 billion in its semiconductor manufacturing operations in Arizona. This latest investment includes the construction and expansion of:
#
# - Six advanced semiconductor fabrication plants (fabs)
# - Two advanced packaging facilities
# - A research and development (R&D) center
#
# The investment timeline includes:
#
# - An initial $65 billion invested to establish three fabs, with the first fab starting mass production of 4 nm chips in early 2025 and plans for 3 nm and 2 nm chip production in the following years.
# - In March 2025, an additional $100 billion investment was announced to build three more fabs, two advanced packaging facilities, and an R&D center, bringing the total to $165 billion.
# - A land purchase of 900 acres adjacent to existing facilities in January 2026, indicating potential plans for further fab expansions.
#
# This massive capital deployment aims to enhance U.S. semiconductor production capacity, particularly to meet increasing demand for advanced chips used in AI, high-performance computing, and other cutting-edge technologies.
#
# Sources:
# - Arizona Commerce Authority: [President Trump, TSMC Announce $100 Billion Investment in Arizona](https://www.azcommerce.com/news-events/news/2025/3/president-trump-tsmc-announce-100-billion-investment-in-arizona/?utm_source=openai)
# - Wikipedia: [TSMC Arizona](https://en.wikipedia.org/wiki/TSMC_Arizona?utm_source=openai)
# - MacDaily News: [TSMC Land Purchase Drives Total $165 Billion Investment](https://macdailynews.com/2026/01/16/major-apple-supplier-tsmc-boosts-u-s-footprint-with-arizona-land-purchase-driving-total-165-billion-investment/amp/?utm_source=openai)</div>

# %% [markdown]
# ### **[Complete Coding STEP-3.2 and STEP 3.3]**:
# Now we'll define the **evaluator agent**:
# - draft -> **EVALUATOR (LLM)** -> evaluation
#
# You will first update the system_prompt as you see fit (STEP 3.2) and the user_prompt as indicated (STEP 3.3). You will then execute the cell and examine the evaluation.

# %%
#########################################################################
##### ONLY CODE AS INDICATED - DO NOT ALTER THE CELL IN  ANY OTHER WAY!!!
#########################################################################

# STEP-3.2: You have been provided with a system_prompt for the evaluator.
#           Feel free to update the system_prompt if required.
#           But you MUST NOT change the role of the evaluator.
evaluation_system_prompt = (
  f"""
  You are a critical evaluator.
  Your job is to evaluate and suggest improvements, not to rewrite the content.
  Be specific and constructive.
  """
)

# STEP-3.3: You have been provided with a starter user_prompt for the evaluator.
#           It takes the draft from the drafter, and evaluates it.
#           Update the evaluation steps below to provide more concrete guidance to the evaluator.
evaluation_user_prompt = (
    f"""
    Draft from drafter:{draft}
    Evaluation Steps:
    1) Suggest improvements to the draft.
    2) Check whether the draft directly answers the full question.
    3) Check whether the latest total investment amount is stated clearly and early in the response.
    4) Check whether the response clearly explains what the investment includes.
    5) Check whether the response is concise, well-structured, and supported by sources.
    """
)

# Have the LLM model reflect on the draft and provide its evaluation (without web_search).
# We do not provide access to web_search becuase we want the critique to be based on reasoning, not new facts.
evaluation, query_details = run_openai_query(evaluation_system_prompt, evaluation_user_prompt, tools=[])

show("----- EVALUATION (WITHOUT WEB_SEARCH) -----", "")
show("Evaluation", evaluation)
# Out:
#      <h4>----- EVALUATION (WITHOUT WEB_SEARCH) -----</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;"></div>
#      <h4>Evaluation</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">1) Improvements to the draft:
# - The draft could benefit from a more concise opening sentence that immediately states the total investment amount and its significance.
# - The description of the investment timeline is somewhat detailed but could be structured for easier readability, for example by grouping related information or emphasizing milestones.
# - Some phrasing can be streamlined to avoid redundancy (e.g., "the investment timeline includes" followed by dates and details could be tightened).
# - Adding a brief concluding sentence summarizing the strategic importance of the investment might enhance clarity.
# - Check for updating or confirming source names, as the link referencing "President Trump" seems out-of-date for a 2025 event; the draft might clarify this or confirm currency of sources.
#
# 2) Does the draft directly answer the full question?
# - The draft effectively outlines the total investment, timeline, and components of the investment, which presumably aligns with explaining TSMC's investment in Arizona as requested.
# - If the original question specifically asks "how much TSMC is investing" and "what the investment includes," the draft answers both parts well.
#
# 3) Is the latest total investment amount stated clearly and early?
# - The total investment amount of "$165 billion" is mentioned right in the first sentence, which is good for clarity and emphasis.
#
# 4) Does the response clearly explain what the investment includes?
# - Yes, it explicitly lists the fabs, packaging facilities, and R&D center, and references the timeline for their establishment and production capacity.
# - The mention of land purchase hints at further expansion, which adds useful context.
#
# 5) Is the response concise, well-structured, and supported by sources?
# - The response is fairly detailed and generally structured, but slight reorganizing could improve flow.
# - The inclusion of multiple reputable sources is valuable; however, source reliability and currency should be double-checked.
# - Some sentences might be condensed to enhance conciseness and readability.
#
# Summary of suggestions:
# - Make the opening sentence more direct and concise.
# - Organize timeline details in a clearer format, possibly bulleted or separated by year.
# - Add a final statement about the strategic importance or expected impact of the investment.
# - Review and confirm sources for currency and relevance.
# - Edit for minor redundancies and enhance overall flow.</div>

# %% [markdown]
# ### **[Complete Coding STEP-3.4 and STEP 3.5]**:
#
# Finally, we'll define the **revisor agent**:
# - draft & evaluation -> **REVISER (LLM)** -> revision
#
# You will first update the system_prompt as you see fit (STEP 3.4) and the user_prompt as indicated (STEP 3.5). You will then execute the cell and examine the revision.

# %%
#########################################################################
##### ONLY CODE AS INDICATED - DO NOT ALTER THE CELL IN  ANY OTHER WAY!!!
#########################################################################

# STEP-3.4: You have been provided with a system_prompt for the reviser.
#           Feel free to update the system_prompt if required.
#           But you MUST NOT change the role of the reviser.
revision_system_prompt = (
  f"""
  You are revising a draft based on an evaluator's feedback.
  Your job is to make only minimal edits to the draft.
  Use only the facts already written in the draft.
  Do not introduce, infer, or replace any numbers, dates, quantities, facilities, timelines, or claims.
  Keep the same factual content as the draft and only improve wording and organization.
  """
)

# STEP-3.5: You have been provided with a starter user_prompt for the reviser.
#           It revises the draft from the drafter based on the evaluation from the evaluator.
#           Update the revision steps below to provide more concrete guidance to the reviser.
revision_user_prompt = (
    f"""
    Draft from drafter:{draft}
    Evaluation from evaluator:{evaluation}
    Revision Steps:
    1) Make only minimal edits to the draft.
    2) Preserve every factual detail from the draft exactly as written.
    3) Do not add or replace any numbers, dates, job figures, timelines, or technical details.
    4) Reorganize the wording so the first sentence directly answers the question and states the total investment clearly.
    5) Keep the explanation of what the investment includes.
    6) Keep the same sources from the draft.
    """
)

# Have the LLM model revise the draft based on the evaluation (without web_search).
# We do not provide access to web_search becuase we want the revision to integrate, not expand.
revision, query_details = run_openai_query(revision_system_prompt, revision_user_prompt, tools=[])

show("----- Revision (WITHOUT TOOLS) -----", "")
show("Revision", revision)
# Out:
#      <h4>----- Revision (WITHOUT TOOLS) -----</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;"></div>
#      <h4>Revision</h4>
#      <div style="white-space: pre-wrap; padding-left: 24px;">As of early 2026, Taiwan Semiconductor Manufacturing Company (TSMC) has announced a total investment of approximately $165 billion in its semiconductor manufacturing operations in Arizona, marking a significant expansion of U.S. chip production capacity. This investment includes the construction and expansion of:
#
# - Six advanced semiconductor fabrication plants (fabs)
# - Two advanced packaging facilities
# - A research and development (R&D) center
#
# Key milestones in the investment timeline are:
#
# - An initial $65 billion invested to establish three fabs, with the first fab starting mass production of 4 nm chips in early 2025 and plans for 3 nm and 2 nm chip production in the following years.
# - In March 2025, an additional $100 billion investment was announced to build three more fabs, two advanced packaging facilities, and an R&D center, bringing the total to $165 billion.
# - A land purchase of 900 acres adjacent to existing facilities in January 2026, indicating potential plans for further fab expansions.
#
# This substantial investment aims to enhance U.S. semiconductor production capacity to meet growing demand for advanced chips used in AI, high-performance computing, and other cutting-edge technologies.
#
# Sources:
# - Arizona Commerce Authority: [President Trump, TSMC Announce $100 Billion Investment in Arizona](https://www.azcommerce.com/news-events/news/2025/3/president-trump-tsmc-announce-100-billion-investment-in-arizona/?utm_source=openai)
# - Wikipedia: [TSMC Arizona](https://en.wikipedia.org/wiki/TSMC_Arizona?utm_source=openai)
# - MacDaily News: [TSMC Land Purchase Drives Total $165 Billion Investment](https://macdailynews.com/2026/01/16/major-apple-supplier-tsmc-boosts-u-s-footprint-with-arizona-land-purchase-driving-total-165-billion-investment/amp/?utm_source=openai)</div>

# %% [markdown]
#  ### Once you've settled on the final version of STEPS 3.1-3.5 above remember to do a "Runtime -> Restart session and run all" and "Ctrl-s" before you download your file for submission.
